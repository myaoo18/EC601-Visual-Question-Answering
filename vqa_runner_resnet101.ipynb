# %%
# Pre-process images with ResNet101 weights ported from VQA 1.0 Abstract Scene: https://visualqa.org/vqa_v1_download.html

# %%
# !python preprocess-images.py
# Out:
# Downloading: "https://s3.amazonaws.com/pytorch/models/resnet101-5d3b4d8f.pth" to /usr3/graduate/luzffy/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
# 100%|████████████████████████████████████████| 170M/170M [00:01<00:00, 90.4MB/s]
# /share/pkg.7/pytorch/1.9.0/install/lib/python3.8/site-packages/torchvision/transforms/transforms.py:310: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   warnings.warn("The use of the transforms.Scale transform is deprecated, " +
# found 20000 images in mscoco/train2015
# found 10000 images in mscoco/val2015
# ...

# %%
# Pre-process vocabularies for questions and answers from VQA 1.0 Abstract Scene: https://visualqa.org/vqa_v1_download.html

# %%
# !python preprocess-vocab.py

# %%
# Now start training the model

# %%
# !python train.py
# Out:
# will save to logs/2021-11-21_21:43:32.pth
# /projectnb2/ece601/TeamVQA/pytorch-vqa/model.py:86: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   init.xavier_uniform(self.embedding.weight)
# /projectnb2/ece601/TeamVQA/pytorch-vqa/model.py:44: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   init.xavier_uniform(m.weight)
# train E000:   0% 0/469 [00:00<?, ?it/s]/share/pkg.7/pytorch/1.9.0/install/lib/python3.8/site-packages/torch/nn/modules/rnn.py:682: UserWarning: RNN module weights are not part of single contiguous chunk of memory. This means they need to be compacted at every call, possibly greatly increasing memory usage. To compact weights again call flatten_parameters(). (Triggered internally at  /pytorch/aten/src/ATen/native/cudnn/RNN.cpp:924.)
#   result = _VF.lstm(input, batch_sizes, hx, self._flat_weights, self.bias,
# ...

# %%
# Plot diagram based on training result

# %%
# !python view-log.py ./logs/ResNet_resnet101_50epoch.pth
